# %% [markdown]
# # TASK-5
# ####   AIRSS1127
# #### PRIYANSHU LASOD
# #### Subject:Function
#
# # Explanation of the Task:
# #### To define the function, use the term def, followed by the function name.
# #### Add parameters to the function.
# #### Add statements that should be executed by the functions.
# #### End the function with a return statement; otherwise, the function will return an object. None

# %% [markdown]
# ## Q1. Given a list of integers, write a function to return the sum of all prime numbers in that list.

# %%
integers=[1,2,3,4,5,6,7,8,9]
sum_primes=0
for n in integers:
    n=int(n)
    isPrime=True
    if n > 1:
    
        for i in range(2, n):
            if (n % i) == 0:
                isPrime=False
                break
        if isPrime:
            sum_primes+=n


print(str(sum_primes))
# Out:
# 17

# %% [markdown]
# ## Q2. Given a list of integers, write a function to check whether the list is strictly increasing or not.

# %%
test_list = [1, 4, 5, 7, 8, 10]
print ("Original list : " + str(test_list))
pre = bool(lambda test_list: reduce(lambda i, j: j if i < j else 9999, test_list) != 9999)
print ("Is list strictly increasing ? : " + str(pre))
# Out:
# Original list : [1, 4, 5, 7, 8, 10]
# Is list strictly increasing ? : True

# %% [markdown]
# ## Q3. Write a function to check whether a given list is expanding or not (the difference between adjacent elements should keep on increasing).

# %%
import numpy as np
ini_list = np.array([5, 28, 61, 120, 320, 550])
print("intial_list", str(ini_list))
diff_list = np.diff(ini_list)
print ("difference list: ", str(diff_list))
# Out:
# intial_list [  5  28  61 120 320 550]
# difference list:  [ 23  33  59 200 230]

# %% [markdown]
# ## Q4. Write a function to calculate all permutations of a given string. (Without using itertools)

# %%
def toString(List): 
    return ''.join(List) 

def permute(a, l, r): 
    if l==r: 
        print (toString(a) )
    else: 
        for i in range(l,r+1): 
            a[l], a[i] = a[i], a[l] 
            permute(a, l+1, r) 
            a[l], a[i] = a[i], a[l] # backtrack 

# Driver program to test the above function 

string = "LOVE"
n = len(string) 
a = list(string) 
permute(a, 0, n-1)
# Out:
# LOVE
# LOEV
# LVOE
# LVEO
# LEVO
# LEOV
# OLVE
# OLEV
# OVLE
# OVEL
# OEVL
# OELV
# VOLE
# VOEL
# VLOE
# VLEO
# VELO
# VEOL
# EOVL
# EOLV
# EVOL
# EVLO
# ELVO
# ELOV

# %%
 def permutations(string, step = 0):
    if step == len(string):
        print( "".join(string))
    for i in range(step, len(string)):
        string_copy = [c for c in string]
        string_copy[step], string_copy[i] =string_copy[i], string_copy[step]
        permutations(string_copy, step + 1)
print (permutations ('love'))
# Out:
# love
# loev
# lvoe
# lveo
# levo
# leov
# olve
# olev
# ovle
# ovel
# oevl
# oelv
# vole
# voel
# vloe
# vleo
# velo
# veol
# eovl
# eolv
# evol
# evlo
# elvo
# elov
# None

# %%
def permutations(s):
    base = len(s)
    for n in range(base**base):
        yield "".join(s[n // base**(base-d-1) % base] for d in range(base))

for r in permutations("love"):
    print(r)
# Out:
# llll
# lllo
# lllv
# llle
# llol
# lloo
# llov
# lloe
# llvl
# llvo
# llvv
# llve
# llel
# lleo
# llev
# llee
# loll
# lolo
# lolv
# lole
# lool
# looo
# loov
# looe
# lovl
# lovo
# lovv
# love
# loel
# loeo
# loev
# loee
# lvll
# lvlo
# lvlv
# lvle
# lvol
# lvoo
# lvov
# lvoe
# lvvl
# lvvo
# lvvv
# lvve
# lvel
# lveo
# lvev
# lvee
# lell
# lelo
# lelv
# lele
# leol
# leoo
# leov
# leoe
# levl
# levo
# levv
# leve
# leel
# leeo
# leev
# leee
# olll
# ollo
# ollv
# olle
# olol
# oloo
# olov
# oloe
# olvl
# olvo
# olvv
# olve
# olel
# oleo
# olev
# olee
# ooll
# oolo
# oolv
# oole
# oool
# oooo
# ooov
# oooe
# oovl
# oovo
# oovv
# oove
# ooel
# ooeo
# ooev
# ooee
# ovll
# ovlo
# ovlv
# ovle
# ovol
# ovoo
# ovov
# ovoe
# ovvl
# ovvo
# ovvv
# ovve
# ovel
# oveo
# ovev
# ovee
# oell
# oelo
# oelv
# oele
# oeol
# oeoo
# oeov
# oeoe
# oevl
# oevo
# oevv
# oeve
# oeel
# oeeo
# oeev
# oeee
# vlll
# vllo
# vllv
# vlle
# vlol
# vloo
# vlov
# vloe
# vlvl
# vlvo
# vlvv
# vlve
# vlel
# vleo
# ...
